# %%
# list
# Out:
# [12, 15, 20, 25, 30]
# 15

# %%
# List Slicing
print(ages[2:])
# Out:
# [20, 25, 30]

# %%
x = [1, 2, 3, 4, 5]

import numpy as np

y = np.array(x)

print(y)

# %%
list_a = [1, 2, 3]

student_data = {
    "name" : "John Doe",
    "age" : 20,
    "cgpas" : [3.5, 3.6, 3.7]
}

print(student_data["cgpas"][1])
# Out:
# 3.6

# %%
data = {
    "temp" : [30, 32, 28],
    "aqi" : [100, 150, 80],
    "is_raining" : [True, False, True]
}

print(data["is_raining"][2])
# Out:
# True

# %%
import pandas as pd
df = pd.DataFrame(data)

df.head()
# Out:
#    temp  aqi  is_raining
# 0    30  100        True
# 1    32  150       False
# 2    28   80        True
