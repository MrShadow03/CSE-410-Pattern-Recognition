# %%
import pandas as pd
from scipy.spatial.distance import euclidean, cityblock, cosine

# %%
df = pd.read_csv('../datasets/titanic/titanic_cleaned.csv')

# %%
passenger1 = df.iloc[0][['Age', 'Fare', 'Pclass']].values
passenger2 = df.iloc[50][['Age', 'Fare', 'Pclass']].values

euclidean_distance = euclidean(passenger1, passenger2)
print("Euclidean Distance: ", euclidean_distance)

manhattan_distance = cityblock(passenger1, passenger2)
print("Manhattan Distance: ", manhattan_distance)

cosine_distance = cosine(passenger1, passenger2)
print("cosine Distance: ", cosine_distance)
# Out:
# Euclidean Distance:  35.73781479399657
# Manhattan Distance:  47.4375
# cosine Distance:  0.5224791407284491
